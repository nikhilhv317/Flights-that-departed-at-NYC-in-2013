# %% [markdown]
# # DESCRIPTION :
# On-time data for all flights that departed NYC(New York City) in 2013.

# %% [markdown]
# # BUSINESS CONTEXT :
# <font color=red>A data science team is working on an important project related to airports and optimization.
# You are a new team member and was hired as junior data scientist. Each team member has received a task and your task is to
# check if you can say that Delta Airlines (DL) flights are delayed more thanUnited Airlines (UA) flights ?
# The file (data source) is already available to start your analysis.
# To solve this problem you will need to use statistical concepts and python programming language
# that are the foundation of modern machine learning development.</font>

# %% [markdown]
# # Task 1:

# %% [markdown]
# ### Create a Jupyter Notebook to present your analysis and perform an exploratory data analysis (EDA) on flights.csv file.

# %%
import numpy as np
import pandas as pd
data = pd.read_csv('F:/data_science/flights.csv')
data
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
data.isnull().sum()
# Out:
# year                 0
# month                0
# day                  0
# dep_time          8255
# sched_dep_time       0
# dep_delay         8255
# arr_time          8713
# sched_arr_time       0
# arr_delay         9430
# carrier              0
# flight               0
# tailnum           2512
# origin               0
# dest                 0
# air_time          9430
# distance             0
# hour                 0
# minute               0
# time_hour            0
# dtype: int64

# %%
data.shape
# Out:
# (336776, 19)

# %%
data[['dep_time','dep_delay','arr_time','arr_delay','air_time']] = data[['dep_time','dep_delay','arr_time','arr_delay','air_time']].fillna(value=data[['dep_time','dep_delay','arr_time','arr_delay','air_time']].mean()) 

data
#df.fillna(method='ffill', inplace=True)
# Out:
#         year  month  day     dep_time  sched_dep_time  dep_delay     arr_time  \
# 0       2013      1    1   517.000000             515    2.00000   830.000000
# 1       2013      1    1   533.000000             529    4.00000   850.000000
# 2       2013      1    1   542.000000             540    2.00000   923.000000
# 3       2013      1    1   544.000000             545   -1.00000  1004.000000
# 4       2013      1    1   554.000000             600   -6.00000   812.000000
# ...      ...    ...  ...          ...             ...        ...          ...
# 336771  2013      9   30  1349.109947            1455   12.63907  1502.054999
# 336772  2013      9   30  1349.109947            2200   12.63907  1502.054999
# 336773  2013      9   30  1349.109947            1210   12.63907  1502.054999
# 336774  2013      9   30  1349.109947            1159   12.63907  1502.054999
# 336775  2013      9   30  1349.109947             840   12.63907  1502.054999
#
# ...

# %%
data.isnull().sum()
# Out:
# year                 0
# month                0
# day                  0
# dep_time             0
# sched_dep_time       0
# dep_delay            0
# arr_time             0
# sched_arr_time       0
# arr_delay            0
# carrier              0
# flight               0
# tailnum           2512
# origin               0
# dest                 0
# air_time             0
# distance             0
# hour                 0
# minute               0
# time_hour            0
# dtype: int64

# %%
data.describe()
# Out:
#            year          month            day       dep_time  sched_dep_time  \
# count  336776.0  336776.000000  336776.000000  336776.000000   336776.000000
# mean     2013.0       6.548510      15.710787    1349.109947     1344.254840
# std         0.0       3.414457       8.768607     482.260302      467.335756
# min      2013.0       1.000000       1.000000       1.000000      106.000000
# 25%      2013.0       4.000000       8.000000     915.000000      906.000000
# 50%      2013.0       7.000000      16.000000    1349.109947     1359.000000
# 75%      2013.0      10.000000      23.000000    1737.000000     1729.000000
# max      2013.0      12.000000      31.000000    2400.000000     2359.000000
#
#            dep_delay       arr_time  sched_arr_time      arr_delay  \
# count  336776.000000  336776.000000   336776.000000  336776.000000
# mean       12.639070    1502.054999     1536.380220       6.895377
# std        39.714191     526.320657      497.457142      44.003969
# ...

# %%
datacorr = data.corr()
datacorr
# Out:
#                 year     month       day  dep_time  sched_dep_time  dep_delay  \
# year             NaN       NaN       NaN       NaN             NaN        NaN
# month            NaN  1.000000  0.002942 -0.003882       -0.004573  -0.019798
# day              NaN  0.002942  1.000000 -0.000462       -0.000014   0.000415
# dep_time         NaN -0.003882 -0.000462  1.000000        0.942741   0.260231
# sched_dep_time   NaN -0.004573 -0.000014  0.942741        1.000000   0.196412
# dep_delay        NaN -0.019798  0.000415  0.260231        0.196412   1.000000
# arr_time         NaN -0.002486 -0.005470  0.660297        0.634313   0.028621
# sched_arr_time   NaN -0.004173 -0.002403  0.775640        0.783342   0.158639
# arr_delay        NaN -0.017132 -0.000315  0.231908        0.171473   0.909887
# flight           NaN -0.000834 -0.001791  0.041172        0.036495   0.053709
# air_time         NaN  0.010767  0.002207 -0.014594       -0.015316  -0.022285
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams
# %matplotlib inline
plt.rcParams['figure.figsize'] = (20, 10)
sns.heatmap(datacorr.corr(), annot = True, cmap = 'viridis')
plt.title('Heatmap of the Dataset', fontsize = 30)
plt.show()

# %% [markdown]
# # Task 2:

# %% [markdown]
# ### <font color=blue>Create at least 5 different views (reports) to the team using the imported dataset. The reports should be composed of a description, charts and tables based on some selected columns. These reports can give some insights to the team about the airport operation and potential optimizations.</font>

# %%
flights_speed_dep_df = data.groupby(['carrier'],as_index = False).agg({'dep_delay':'mean'})
print(flights_speed_dep_df)
flights_speed_dep_df.plot(kind='bar', title ="Speed of Carriers from New York to Seattle",figsize=(5,5),legend=True, fontsize=12)
plt.xlabel('Carrier')
plt.ylabel('Mean Departure Delay')
plt.show()
plt.close()

flights_speed_arr_df = data.groupby(['carrier'],as_index = False).agg({'arr_delay':'mean'})
print(flights_speed_arr_df)
flights_speed_arr_df.plot(kind='bar', title ="Speed of Carriers from New York to Seattle",figsize=(5,5),legend=True, fontsize=12)
plt.xlabel('Carrier')
plt.ylabel('Mean Arrival Delay')
plt.show()
plt.close()
# Out:
#    carrier  dep_delay
# 0       9E  16.494647
# 1       AA   8.664776
# 2       AS   5.823919
# 3       B6  13.019252
# 4       DL   9.288984
# 5       EV  19.574941
# 6       F9  20.182361
# 7       FL  18.589771
# 8       HA   4.900585
# 9       MQ  10.649605
# 10      OO  12.591163
# 11      UA  12.112306
# 12      US   4.068353
# 13      VX  12.868038
# 14      WN  17.632399
# 15      YV  18.403973
#    carrier  arr_delay
# 0       9E   7.349080
# 1       AA   0.520339
# 2       AS  -9.813058
# 3       B6   9.430488
# 4       DL   1.693675
# 5       EV  15.292827
# 6       F9  21.832966
# 7       FL  19.771198
# 8       HA  -6.915205
# 9       MQ  10.574865
# 10      OO  11.458942
# 11      UA   3.608244
# 12      US   2.293204
# 13      VX   1.810187
# 14      WN   9.597298
# 15      YV  14.735502

# %%
plt.figure(figsize=(5,5))
delay_mon_grp = data.groupby(['month'],as_index = False).agg({'dep_delay':'mean'})
delay_mon_grp['dep_delay'].plot()
plt.xlabel('Month')
plt.ylabel('Mean departure delay')
plt.show()

# %%
#Airport & Airline flight Information
carrier_count = data['carrier'].value_counts()
carrier_count
# Out:
# UA    58665
# B6    54635
# EV    54173
# DL    48110
# AA    32729
# MQ    26397
# US    20536
# 9E    18460
# WN    12275
# VX     5162
# FL     3260
# AS      714
# F9      685
# YV      601
# HA      342
# OO       32
# Name: carrier, dtype: int64

# %%
data.boxplot('dep_time','origin', rot = 40, figsize=(6,6))

plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
data['carrier'].value_counts().plot.pie(autopct='%1.2f%%',ax=ax[1],shadow=False)                                                  
ax[1].set_title('Flight % of Carrier')
ax[1].set_ylabel('')
sns.countplot('carrier',order = data['carrier'].value_counts().index, data=data,ax=ax[0])
ax[0].set_title('Frequency Distribution of Carriers')
ax[0].set_ylabel('Number of Flights')
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Monthly Average Departure Departure Delay

monthly_delay = data.groupby(['month'], as_index=False).agg({'dep_delay': 'mean'})
monthly_delay['dep_delay']=np.round(monthly_delay['dep_delay'],0)
sns.catplot(x='month', y='dep_delay',data=monthly_delay, kind='bar')
plt.title("Monthly Average Departure Delay") 
plt.plot()
plt.show()

# %% [markdown]
# # Task 3:

# %% [markdown]
# ### <font color=orange>Create a new dataset named (pop_data) with flight data from airlines UA (United Airlines) and DL (Delta Airlines). The data set must contain only two columns, company name and delayed arrival flights. The data must be extracted from dataset flights.csv to build the pop_data dataset. The dataset should be limited to no more than 20,000 rows per airlines.</font>

# %%
data.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
#
#    distance  hour  minute             time_hour
# 0      1400     5      15  2013-01-01T05:00:00Z
# ...

# %%
data1 = data.loc[(data.carrier=='UA')]
data2 = data.loc[(data.carrier=='DL')]
data3 = pd.concat([data1,data2])
data3
##ufo.loc[ufo.City=='Oakland', 'State']
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 5       2013      1    1     554.0             558       -4.0     740.0
# 12      2013      1    1     558.0             600       -2.0     924.0
# 13      2013      1    1     558.0             600       -2.0     923.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336670  2013      9   30    1955.0            2000       -5.0    2219.0
# 336674  2013      9   30    1956.0            1825       91.0    2208.0
# 336715  2013      9   30    2041.0            2045       -4.0    2147.0
# 336718  2013      9   30    2050.0            2045        5.0      20.0
# 336744  2013      9   30    2121.0            2100       21.0    2349.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
pop_data = data3.loc[:,['carrier','arr_delay']]
pop_data1=pop_data.head()
pop_data2=pop_data.tail()

print(pop_data1)
print(pop_data2)
pop_data
# Out:
#    carrier  arr_delay
# 0       UA       11.0
# 1       UA       20.0
# 5       UA       12.0
# 12      UA        7.0
# 13      UA      -14.0
#        carrier  arr_delay
# 336670      DL      -11.0
# 336674      DL       47.0
# 336715      DL      -21.0
# 336718      DL      -33.0
# 336744      DL      -25.0
#        carrier  arr_delay
# 0           UA       11.0
# 1           UA       20.0
# 5           UA       12.0
# 12          UA        7.0
# 13          UA      -14.0
# ...        ...        ...
# 336670      DL      -11.0
# 336674      DL       47.0
# 336715      DL      -21.0
# 336718      DL      -33.0
# 336744      DL      -25.0
#
# [106775 rows x 2 columns]

# %% [markdown]
# # Task 4:

# %% [markdown]
# ### <font color=purple>Create two new datasets (“dl” and “ua”) of 1000 observations each from the" pop_data” dataset only with data from the DL (Delta Airlines) for “dl” and only data from UA (United Airlines) for “ua” . Tip: Include a column called sample_id populated with number 0 for the first sample and 1 for the second sample</font>

# %%
#pop_data1
categorical = ['carrier']
survivaldata = pd.get_dummies(pop_data, columns = categorical)
#ua = survivaldata.head(1000)
#dl = survivaldata.tail(1000)

# %%
survivaldata
# Out:
#         arr_delay  carrier_DL  carrier_UA
# 0            11.0           0           1
# 1            20.0           0           1
# 5            12.0           0           1
# 12            7.0           0           1
# 13          -14.0           0           1
# ...           ...         ...         ...
# 336670      -11.0           1           0
# 336674       47.0           1           0
# 336715      -21.0           1           0
# 336718      -33.0           1           0
# 336744      -25.0           1           0
#
# [106775 rows x 3 columns]

# %%
dl = pd.DataFrame(survivaldata.loc[:,'carrier_DL'])
dl
# Out:
#         carrier_DL
# 0                0
# 1                0
# 5                0
# 12               0
# 13               0
# ...            ...
# 336670           1
# 336674           1
# 336715           1
# 336718           1
# 336744           1
#
# [106775 rows x 1 columns]

# %%
ua = pd.DataFrame(survivaldata.loc[:,'carrier_UA'])
ua
# Out:
#         carrier_UA
# 0                1
# 1                1
# 5                1
# 12               1
# 13               1
# ...            ...
# 336670           0
# 336674           0
# 336715           0
# 336718           0
# 336744           0
#
# [106775 rows x 1 columns]

# %% [markdown]
# # Task 5:

# %% [markdown]
# ### <font color=maroon>Create a new dataset (samples) containing the data of the 2 samples created in the previous item to be used in future analysis.Task</font>

# %%
samples = pd.concat([ua,dl])

# %%
samples
# Out:
#         carrier_UA  carrier_DL
# 0              1.0         NaN
# 1              1.0         NaN
# 5              1.0         NaN
# 12             1.0         NaN
# 13             1.0         NaN
# ...            ...         ...
# 336670         NaN         1.0
# 336674         NaN         1.0
# 336715         NaN         1.0
# 336718         NaN         1.0
# 336744         NaN         1.0
#
# [213550 rows x 2 columns]

# %%
samples.to_csv('samples1.csv')

# %% [markdown]
# # Task 6 :

# %% [markdown]
# ### <font color=green>For each sample (“dl” and “ua”) calculate de standard error and the mean.</font>

# %%
import scipy as sp

# %% [markdown]
# ## Mean

# %%
print(np.mean(ua))
# Out:
# carrier_UA    0.549426
# dtype: float64

# %%
print(np.mean(dl))
# Out:
# carrier_DL    0.450574
# dtype: float64

# %% [markdown]
# ## Standard error

# %%
np.std(ua, ddof=1) / np.sqrt(np.size(ua))
# Out:
# carrier_UA    0.001523
# dtype: float64

# %%
np.std(dl, ddof=1) / np.sqrt(np.size(dl))
# Out:
# carrier_DL    0.001523
# dtype: float64

# %% [markdown]
# # Task 7 :

# %% [markdown]
# ## <font color=olive>For each mean calculated before we need to define the “confidence intervals” in this case 95% confidence interval. It means calculate lower and upper values.</font>

# %%
from scipy import stats
import statsmodels.stats.api as sms
import scipy.stats as st

sms.DescrStatsW(survivaldata).tconfint_mean()
# Out:
# (array([2.4918117 , 0.44758923, 0.54644196]),
#  array([2.99936747, 0.45355804, 0.55241077]))

# %%
z_critical = stats.norm.interval(0.95)
z_critical
# Out:
# (-1.959963984540054, 1.959963984540054)

# %%
mean = np.mean(samples)
mean
# Out:
# carrier_UA    0.549426
# carrier_DL    0.450574
# dtype: float64

# %%
sigma = np.std(samples)
sigma
# Out:
# carrier_UA    0.497551
# carrier_DL    0.497551
# dtype: float64

# %%
n = len(samples)
n
# Out:
# 213550

# %%
import math
standard_error = sigma / math.sqrt(n)
standard_error
# Out:
# carrier_UA    0.001077
# carrier_DL    0.001077
# dtype: float64

# %%
lower = mean - z_critical * standard_error
lower
# Out:
# carrier_UA    0.551537
# carrier_DL    0.448463
# dtype: float64

# %%
upper = mean + z_critical * standard_error
upper
# Out:
# carrier_UA    0.547316
# carrier_DL    0.452684
# dtype: float64

# %% [markdown]
# # Task 8 :

# %% [markdown]
# ### <font color=navy>After these set of previous calculations it was requested that you take the T-TEST concept and apply it on your 2 groups of data (“means”) to let your team knows if Delta Airlines (DL) flights are delayed more than United Airlines (UA) flights ?</font>

# %% [markdown]
# ### one sample t-test

# %%
print("skewness of United Airlines",stats.skew(ua))
print("skewness of Delta Airlines",stats.skew(dl))
# Out:
# skewness of United Airlines [-0.19867857]
# skewness of Delta Airlines [0.19867857]

# %%
stats.ttest_1samp(ua,21.0)
# Out:
# Ttest_1sampResult(statistic=array([-13430.76081451]), pvalue=array([0.]))

# %% [markdown]
# ### two sample t-test

# %%
stats.ttest_ind(ua,dl)
# Out:
# Ttest_indResult(statistic=array([45.90592895]), pvalue=array([0.]))
